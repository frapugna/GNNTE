# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from data_visualization import *
from _performance_computation import *

# %% [markdown]
# # Datasets Data Distribution

# %% [markdown]
# ## WikiData

# %% [markdown]
# ### Original Distribution

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/all_samples.csv','table_overlap')

# %% [markdown]
# ### No tables repeated distribution

# %% [markdown]
# 455252_52350_52530

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/train.csv','table_overlap')

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/test.csv','table_overlap')

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/valid.csv','table_overlap')

# %% [markdown]
# ## Gittables

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/labelled/old_data/train_stats_cleaned.csv','a%')

# %% [markdown]
# # Experiments

# %% [markdown]
# ## End-To-End embedding generetion execution time

# %% [markdown]
# ### WikiData

# %%
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_wikidata_1M.pkl','rb') as f:
    tmp_wiki = pickle.load(f)

res_wiki = {k:results[k] for k in tmp_wiki.keys()}

# %%
visualize_scatter_plot(res_wiki, logx=True, logy=True)

# %%
visualize_scatter_plot(res_wiki, logx=False, logy=False)

# %% [markdown]
# ### Gittables

# %%
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_gittables_800k.pkl','rb') as f:
    tmp_git = pickle.load(f)

res_git = {k:results[k] for k in tmp_git.keys()}

# %%
visualize_scatter_plot(res_git, logx=True, logy=True)

# %%
visualize_scatter_plot(res_git, logx=False, logy=False)

# %% [markdown]
# ## X: Overlap bins Y: MAE

# %% [markdown]
# ### WikiData

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/test.csv','table_overlap')

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/test_data/performance/1_x_bins_y_MAE/wikitables/455252_52350_52530_labelled.csv', box=True)
# Out:
# Bin: 0.1        n_samples:6689      MAE:0.17253062620896412
# Bin: 0.2        n_samples:10531      MAE:0.14659633099198388
# Bin: 0.3        n_samples:6512      MAE:0.17753841140080406
# Bin: 0.4        n_samples:5221      MAE:0.17767638840391767
# Bin: 0.5        n_samples:1873      MAE:0.19962923914772865
# Bin: 0.6        n_samples:1949      MAE:0.2025533142769245
# Bin: 0.7        n_samples:3004      MAE:0.17238285348545784
# Bin: 0.8        n_samples:3576      MAE:0.132602768127057
# Bin: 0.9        n_samples:5805      MAE:0.13200347809824597
# Bin: 1.0        n_samples:7190      MAE:0.1622755880868869

# %% [markdown]
# ### Gittables

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/labelled/old_data/train_stats_cleaned.csv','a%')

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/labelled/old_data/results/train_with_predicted_and_AE_wiki_450k.csv', box=True)
# Out:
# Bin: 0.1        n_samples:695798      MAE:0.4847406514092339
# Bin: 0.2        n_samples:105553      MAE:0.3475322932047296
# Bin: 0.3        n_samples:68925      MAE:0.4918980529336628
# Bin: 0.4        n_samples:103032      MAE:0.4985665278580531
# Bin: 0.5        n_samples:20157      MAE:0.42153255546319673
# Bin: 0.6        n_samples:4294      MAE:0.22729566147254063
# Bin: 0.7        n_samples:433      MAE:0.16243076224312275
# Bin: 0.8        n_samples:379      MAE:0.22025249007719058
# Bin: 0.9        n_samples:729      MAE:0.31626386986571065
# Bin: 1.0        n_samples:600      MAE:0.26246778918257957

# %% [markdown]
# ## X: percentage of numerical cells Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','perc_num')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'perc_num', box=True)
# Out:
# Bin: 0.1        n_samples:11941      MAE:0.1857374160140066
# Bin: 0.2        n_samples:5682      MAE:0.1670603737149111
# Bin: 0.3        n_samples:6647      MAE:0.14691684218713286
# Bin: 0.4        n_samples:4027      MAE:0.1668184125784473
# Bin: 0.5        n_samples:4595      MAE:0.1570450298619957
# Bin: 0.6        n_samples:3829      MAE:0.15866923670318245
# Bin: 0.7        n_samples:3901      MAE:0.15073179238999782
# Bin: 0.8        n_samples:3673      MAE:0.15991279786419188
# Bin: 0.9        n_samples:5781      MAE:0.1423195584089532
# Bin: 1.0        n_samples:2229      MAE:0.1428120508278455

# %% [markdown]
# ## X: percentage of textual cells Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','perc_text')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'perc_text', box=True)
# Out:
# Bin: 0.1        n_samples:2186      MAE:0.1438407140817462
# Bin: 0.2        n_samples:5794      MAE:0.14308932487115938
# Bin: 0.3        n_samples:3738      MAE:0.15914694022305684
# Bin: 0.4        n_samples:3920      MAE:0.1512529729674092
# Bin: 0.5        n_samples:3696      MAE:0.15689343701236402
# Bin: 0.6        n_samples:4741      MAE:0.15917359774077405
# Bin: 0.7        n_samples:4047      MAE:0.167861313405344
# Bin: 0.8        n_samples:6012      MAE:0.1483659962041774
# Bin: 0.9        n_samples:6321      MAE:0.1625273554867961
# Bin: 1.0        n_samples:2414      MAE:0.18468881352636746

# %% [markdown]
# ## X: area_to_tokens_ratio Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','area_to_tokens_ratio')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'area_to_tokens_ratio', box=True)
# Out:
# Bin: 0.1        n_samples:218      MAE:0.17641808327942152
# Bin: 0.2        n_samples:679      MAE:0.16119123767711538
# Bin: 0.3        n_samples:1430      MAE:0.1654111919490136
# Bin: 0.4        n_samples:3415      MAE:0.16748946683648944
# Bin: 0.5        n_samples:3942      MAE:0.16928267079601986
# Bin: 0.6        n_samples:4377      MAE:0.1754865497253204
# Bin: 0.7        n_samples:4686      MAE:0.1739703992436788
# Bin: 0.8        n_samples:4375      MAE:0.18060297115779161
# Bin: 0.9        n_samples:10970      MAE:0.16005416312965814
# Bin: 1.0        n_samples:12233      MAE:0.1599107428620813

# %% [markdown]
# ## X: small_table_large_table_ratio Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','areas_ratio')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'area_to_tokens_ratio', box=True, only_text=True)
# Out:
# Bin: 0.1        n_samples:88      MAE:0.1819363244220277
# Bin: 0.2        n_samples:290      MAE:0.1638312337512662
# Bin: 0.3        n_samples:646      MAE:0.1698783965142249
# Bin: 0.4        n_samples:1732      MAE:0.16290044096718928
# Bin: 0.5        n_samples:1383      MAE:0.1661958035301145
# Bin: 0.6        n_samples:872      MAE:0.16708693979128014
# Bin: 0.7        n_samples:1035      MAE:0.14055053253608082
# Bin: 0.8        n_samples:660      MAE:0.1631486144297125
# Bin: 0.9        n_samples:1193      MAE:0.21664011710919517
# Bin: 1.0        n_samples:1323      MAE:0.2901490472345287

# %% [markdown]
# ## X: AE Y: overlap_area_AE

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_AE', logx=True, logy=True)

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_AE', logx=False, logy=False)

# %% [markdown]
# In sostanza le overlap + grandi (come numero di celle) tendono ad essere sbagliate di più, notare che in wikidata le tabelle piccole sono + di quelle grandi -> è possibile che il modello abbia imparato a riconoscerle di +

# %% [markdown]
# ## X: AE Y: overlap_area_error

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_error', logx=False, logy=False, limit_y=True)

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_error', logx=True, logy=True)

# %% [markdown]
# ## X: overlap_area_pred Y: overlap_area_true

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=False, logy=False, plot_bisector=True)

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=True, logy=True, plot_bisector=True)

# %% [markdown]
# ## X: overlap_area_pred Y: overlap_area_true

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=False, logy=False, plot_bisector=True, limit_x=True, x_limit_left=0, x_limit_right=3000)

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=True, logy=True, plot_bisector=True)
