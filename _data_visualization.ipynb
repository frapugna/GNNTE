# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from data_visualization import *
from _performance_computation import *

# %% [markdown]
# # Datasets Data Distribution

# %% [markdown]
# ## WikiData

# %% [markdown]
# ### Original Distribution

# %%
original_dataset = pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/wikipedia_datasets/1MR/samples.csv')
show_samples_distribution(original_dataset)
# Out:
# 100%|██████████| 1486091/1486091 [00:00<00:00, 2619968.56it/s]
# {0.8: 179114,
#  0.3: 170101,
#  0.4: 119736,
#  0.9: 142098,
#  0.5: 89382,
#  0.7: 100776,
#  0.6: 70789,
#  0.0: 172623,
#  0.2: 168583,
#  0.1: 272889}

# %% [markdown]
# ### No tables repeated distribution

# %% [markdown]
# 455252_52350_52530

# %%
show_samples_distribution(pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/1M_wikitables_disjointed/455252_52350_52530/train.csv'))
# Out:
# 100%|██████████| 455252/455252 [00:00<00:00, 2341517.39it/s]
# {0.5: 15904,
#  0.8: 55893,
#  0.6: 24241,
#  0.7: 31533,
#  0.3: 39331,
#  0.4: 19390,
#  0.2: 59283,
#  0.1: 96863,
#  0.9: 51051,
#  0.0: 61763}

# %%
show_samples_distribution(pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/1M_wikitables_disjointed/455252_52350_52530/test.csv'))
# Out:
# 100%|██████████| 52350/52350 [00:00<00:00, 2268280.44it/s]
# {0.4: 2204,
#  0.6: 2810,
#  0.9: 5972,
#  0.3: 4928,
#  0.5: 1986,
#  0.8: 7023,
#  0.7: 3402,
#  0.1: 10531,
#  0.2: 6805,
#  0.0: 6689}

# %%
show_samples_distribution(pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/1M_wikitables_disjointed/455252_52350_52530/valid.csv'))
# Out:
# ...
# 100%|██████████| 52530/52530 [00:00<00:00, 2264686.18it/s]
# {0.8: 6326,
#  0.5: 1860,
#  0.6: 2731,
#  0.7: 3458,
#  0.9: 5465,
#  0.3: 4712,
#  0.2: 7086,
#  0.4: 2272,
#  0.1: 11469,
#  0.0: 7151}

# %% [markdown]
# ## Gittables

# %%
git_train = pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/gittables_labelled_no_rep_train_test/train_stats_cleaned.csv')

# %%
show_samples_distribution(git_train)
# Out:
# 100%|██████████| 1000000/1000000 [00:00<00:00, 2664625.25it/s]
# {0.0: 695798,
#  0.2: 69389,
#  0.1: 105553,
#  0.4: 23737,
#  0.3: 102568,
#  0.7: 369,
#  0.6: 399,
#  0.5: 758,
#  0.9: 574,
#  0.8: 755,
#  1: 100}

# %% [markdown]
# # Experiments

# %% [markdown]
# ## End-To-End embedding generetion execution time

# %% [markdown]
# ### Gittables and wikidata joined

# %% [markdown]
# Log-Linear

# %%
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)

visualize_scatter_plot(results)

# %% [markdown]
# Linear Log

# %%
visualize_scatter_plot(results, logx=False, logy=True)

# %% [markdown]
# Log-Log

# %%
visualize_scatter_plot(results, logx=True, logy=True)

# %% [markdown]
# Linear-Linear

# %%
visualize_scatter_plot(results, logx=False, logy=False)

# %% [markdown]
# ### WikiData

# %%
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_wikidata_1M.pkl','rb') as f:
    tmp_wiki = pickle.load(f)

res_wiki = {k:results[k] for k in tmp_wiki.keys()}

# %%
visualize_scatter_plot(res_wiki, logx=True, logy=True)

# %%
visualize_scatter_plot(res_wiki, logx=False, logy=True)

# %%
visualize_scatter_plot(res_wiki, logx=True, logy=False)

# %%
visualize_scatter_plot(res_wiki, logx=False, logy=False)

# %% [markdown]
# ### Gittables

# %%
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/run_data/gen_emb_seq/emb_speed_gittables_800k.pkl','rb') as f:
    tmp_git = pickle.load(f)

res_git = {k:results[k] for k in tmp_git.keys()}

# %%
visualize_scatter_plot(res_git, logx=True, logy=True)

# %%
visualize_scatter_plot(res_git, logx=True, logy=False)

# %%
visualize_scatter_plot(res_git, logx=False, logy=True)

# %%
visualize_scatter_plot(res_git, logx=False, logy=False)

# %% [markdown]
# ## MSE by intervals

# %% [markdown]
# ### WikiData

# %% [markdown]
# ### Gittables

# %%
git_train_base = pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/gittables_labelled_no_rep_train_test/train_stats_cleaned.csv')
show_samples_distribution(git_train_base)
# Out:
# 100%|██████████| 1000000/1000000 [00:00<00:00, 2187794.51it/s]
# {0.0: 695798,
#  0.2: 69389,
#  0.1: 105553,
#  0.4: 23737,
#  0.3: 102568,
#  0.7: 369,
#  0.6: 399,
#  0.5: 758,
#  0.9: 574,
#  0.8: 755,
#  1: 100}

# %% [markdown]
# Trained on: wikidata_450k_no_repetitions

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/gittables_labelled_no_rep_train_test/results/train_with_predicted_and_AE_wiki_450k.csv', box=False)
# Out:
# Bin: 0.1        n_samples:695798      MAE:0.4847406514092339
# Bin: 0.2        n_samples:105553      MAE:0.3475322932047296
# Bin: 0.3        n_samples:68925      MAE:0.4918980529336628
# Bin: 0.4        n_samples:103032      MAE:0.4985665278580531
# Bin: 0.5        n_samples:20157      MAE:0.42153255546319673
# Bin: 0.6        n_samples:4294      MAE:0.22729566147254063
# Bin: 0.7        n_samples:433      MAE:0.16243076224312275
# Bin: 0.8        n_samples:379      MAE:0.22025249007719058
# Bin: 0.9        n_samples:729      MAE:0.31626386986571065
# Bin: 1.0        n_samples:600      MAE:0.26246778918257957

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/Datasets/CoreEvaluationDatasets/gittables_labelled_no_rep_train_test/results/train_with_predicted_and_AE_wiki_450k.csv', box=True)
# Out:
# Bin: 0.1        n_samples:695798      MAE:0.4847406514092339
# Bin: 0.2        n_samples:105553      MAE:0.3475322932047296
# Bin: 0.3        n_samples:68925      MAE:0.4918980529336628
# Bin: 0.4        n_samples:103032      MAE:0.4985665278580531
# Bin: 0.5        n_samples:20157      MAE:0.42153255546319673
# Bin: 0.6        n_samples:4294      MAE:0.22729566147254063
# Bin: 0.7        n_samples:433      MAE:0.16243076224312275
# Bin: 0.8        n_samples:379      MAE:0.22025249007719058
# Bin: 0.9        n_samples:729      MAE:0.31626386986571065
# Bin: 1.0        n_samples:600      MAE:0.26246778918257957
