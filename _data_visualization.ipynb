# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from data_visualization import *
from _performance_overlap_computation import *

# %% [markdown]
# # Datasets Data Distribution

# %% [markdown]
# ## WikiData

# %% [markdown]
# ### Original Distribution

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/all_samples.csv','table_overlap')

# %% [markdown]
# ### No tables repeated distribution

# %% [markdown]
# 455252_52350_52530

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/train.csv','table_overlap')

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/test.csv','table_overlap')

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/valid.csv','table_overlap')

# %% [markdown]
# ## Gittables

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/labelled/old_data/train_stats_cleaned.csv','a%')

# %% [markdown]
# # Experiments

# %% [markdown]
# ## End-To-End embedding generetion execution time

# %% [markdown]
# ### WikiData

# %%
with open('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/gen_emb_seq/mixed/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/gen_emb_seq/wikidata/emb_speed_wikidata_1M.pkl','rb') as f:
    tmp_wiki = pickle.load(f)

res_wiki = {k:results[k] for k in tmp_wiki.keys()}

# %%
visualize_scatter_plot(res_wiki, logx=True, logy=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_scatter_plot(res_wiki, logx=False, logy=False)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Gittables

# %%
with open('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/gen_emb_seq/mixed/emb_speed_git_wiki_full_optimezed_5_iters.pkl', 'rb') as f:
    results = pickle.load(f)
with open('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/gen_emb_seq/gittables/emb_speed_gittables_800k.pkl','rb') as f:
    tmp_git = pickle.load(f)

res_git = {k:results[k] for k in tmp_git.keys()}

# %%
visualize_scatter_plot(res_git, logx=True, logy=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_scatter_plot(res_git, logx=False, logy=False)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## End2End overlap computation compared sloth

# %%
data = pd.read_csv('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/end_2_end_overlap_comparison/t_execs_compared_seconds_full_100tokens_with_test_repeated_for_cossim.csv')
data[['total_time', 'total', 'overlap_computations_repeated']].describe()
# Out:
#           total_time          total  overlap_computations_repeated
# count  199389.000000  200000.000000                  200000.000000
# mean        2.135047       0.225472                       0.000225
# std         4.776387       0.371984                       0.000005
# min         0.000073       0.002961                       0.000218
# 25%         0.000434       0.043648                       0.000223
# 50%         0.001404       0.058642                       0.000224
# 75%         0.030425       0.309944                       0.000225
# max        63.329866      27.098526                       0.001108

# %%
show_scatter_t_exec_sloth_arm('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/end_2_end_overlap_comparison/t_execs_compared_seconds_full_100tokens_with_test_repeated_for_cossim.csv', logx=True, logy=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/francesco.pugnaloni/GNNTE/GNNTE/_performance_computation.py:315: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pd.read_csv('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/end_2_end_overlap_comparison/t_execs_compared_seconds_full_sha256.csv').describe()
# Out:
#                   id             a%     total_time  graphs_generation  \
# count  200000.000000  199389.000000  199389.000000      200000.000000
# mean    99999.500000       0.603910       2.135047           0.186716
# std     57735.171256       0.258045       4.776387           0.349602
# min         0.000000       0.001897       0.000073           0.000701
# 25%     49999.750000       0.500000       0.000434           0.020473
# 50%     99999.500000       0.526316       0.001404           0.026989
# 75%    149999.250000       0.818182       0.030425           0.256192
# max    199999.000000       1.000000      63.329866          25.775709
#
#        embeddings_generation  overlap_computation          total  \
# count          200000.000000        200000.000000  200000.000000
# mean                0.002913             0.000168       0.189798
# std                 0.003542             0.000018       0.350401
# min                 0.001704             0.000136       0.002622
# ...

# %%
show_scatter_t_exec_sloth_arm('/home/francesco.pugnaloni/GNNTE/test_data/t_exec/end_2_end_overlap_comparison/t_execs_compared_seconds_full_sha256.csv', logx=True, logy=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/francesco.pugnaloni/GNNTE/GNNTE/_performance_overlap_computation.py:318: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## X: Overlap bins Y: MAE

# %% [markdown]
# ### WikiTables

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/2_WikiTables/1M_wikitables_disjointed/455252_52350_52530/test.csv','table_overlap')

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/test_data/performance/1_x_bins_y_MAE/wikitables/455252_52350_52530_labelled_sha256.csv', box=True)
# Out:
# Bin: 0.1        n_samples:6689      MAE:0.10724427951005236
# Bin: 0.2        n_samples:10531      MAE:0.12386554182321767
# Bin: 0.3        n_samples:6512      MAE:0.15465808037297948
# Bin: 0.4        n_samples:5221      MAE:0.14680382391980107
# Bin: 0.5        n_samples:1873      MAE:0.16885846823130762
# Bin: 0.6        n_samples:1949      MAE:0.17782123648062687
# Bin: 0.7        n_samples:3004      MAE:0.16000760429467345
# Bin: 0.8        n_samples:3576      MAE:0.13848518634058446
# Bin: 0.9        n_samples:5805      MAE:0.12561701621468854
# Bin: 1.0        n_samples:7190      MAE:0.11261229974957847

# %%
show_mae_per_bin('/home/francesco.pugnaloni/GNNTE/tmp/plot_data_eff_mae_best.csv', box=True, label_true='a%', label_AE='AE_armadillo')
# Out:
# Bin: 0.1        n_samples:10000      MAE:0.08286390318948425
# Bin: 0.2        n_samples:10000      MAE:0.10770446231829915
# Bin: 0.3        n_samples:10000      MAE:0.10183125951269403
# Bin: 0.4        n_samples:10000      MAE:0.12684810508624444
# Bin: 0.5        n_samples:10000      MAE:0.10512867606185834
# Bin: 0.6        n_samples:10000      MAE:0.08013251433306876
# Bin: 0.7        n_samples:10000      MAE:0.05429555185392089
# Bin: 0.8        n_samples:10000      MAE:0.07997116840239002
# Bin: 0.9        n_samples:10000      MAE:0.13813001423328847
# Bin: 1.0        n_samples:2376      MAE:0.06246387839359733

# %%
pd.read_csv('/home/francesco.pugnaloni/GNNTE/tmp/plot_data_eff_mae_best.csv').describe()
# Out:
#                   a%           jsim     jsim_time          josie  \
# count  100000.000000  100000.000000  1.000000e+05  100000.000000
# mean        0.498701       0.459528  2.354115e-03       0.624077
# std         0.289637       0.287070  2.706253e-02       0.269061
# min         0.000000       0.000000  7.152557e-07       0.000000
# 25%         0.250000       0.230088  1.311302e-05       0.434342
# 50%         0.499982       0.420290  3.123283e-05       0.639875
# 75%         0.727273       0.654377  1.509190e-04       0.863636
# max         1.000000       1.000000  1.283983e+00       1.000000
#
#          josie_time  overlap_armadillo   AE_armadillo
# count  1.000000e+05      100000.000000  100000.000000
# mean   9.285575e-04           0.530010       0.089390
# std    1.085664e-02           0.328590       0.105320
# min    4.768372e-07           0.000000       0.000000
# 25%    4.529953e-06           0.244523       0.012092
# 50%    1.120567e-05           0.519733       0.059361
# ...

# %% [markdown]
# ## X: percentage of numerical cells Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','perc_num')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'perc_num', box=True)
# Out:
# Bin: 0.1        n_samples:11941      MAE:0.1857374160140066
# Bin: 0.2        n_samples:5682      MAE:0.1670603737149111
# Bin: 0.3        n_samples:6647      MAE:0.14691684218713286
# Bin: 0.4        n_samples:4027      MAE:0.1668184125784473
# Bin: 0.5        n_samples:4595      MAE:0.1570450298619957
# Bin: 0.6        n_samples:3829      MAE:0.15866923670318245
# Bin: 0.7        n_samples:3901      MAE:0.15073179238999782
# Bin: 0.8        n_samples:3673      MAE:0.15991279786419188
# Bin: 0.9        n_samples:5781      MAE:0.1423195584089532
# Bin: 1.0        n_samples:2229      MAE:0.1428120508278455

# %% [markdown]
# ## X: percentage of textual cells Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','perc_text')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'perc_text', box=True)
# Out:
# Bin: 0.1        n_samples:2186      MAE:0.1438407140817462
# Bin: 0.2        n_samples:5794      MAE:0.14308932487115938
# Bin: 0.3        n_samples:3738      MAE:0.15914694022305684
# Bin: 0.4        n_samples:3920      MAE:0.1512529729674092
# Bin: 0.5        n_samples:3696      MAE:0.15689343701236402
# Bin: 0.6        n_samples:4741      MAE:0.15917359774077405
# Bin: 0.7        n_samples:4047      MAE:0.167861313405344
# Bin: 0.8        n_samples:6012      MAE:0.1483659962041774
# Bin: 0.9        n_samples:6321      MAE:0.1625273554867961
# Bin: 1.0        n_samples:2414      MAE:0.18468881352636746

# %% [markdown]
# ## X: small_table_large_table_ratio Y: MAE

# %%
plot_data_distribution('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv','areas_ratio')

# %%
show_mae_per_bin_text_num('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 'areas_ratio', box=True, only_text=False)
# Out:
# Bin: 0.1        n_samples:829      MAE:0.21804559368757503
# Bin: 0.2        n_samples:1562      MAE:0.1948649905659437
# Bin: 0.3        n_samples:1784      MAE:0.1877745643162385
# Bin: 0.4        n_samples:1850      MAE:0.16643131756198792
# Bin: 0.5        n_samples:2189      MAE:0.15764492854832396
# Bin: 0.6        n_samples:3827      MAE:0.1508280782310957
# Bin: 0.7        n_samples:4451      MAE:0.14682457503433827
# Bin: 0.8        n_samples:6240      MAE:0.15286026530536612
# Bin: 0.9        n_samples:6823      MAE:0.15202684525127075
# Bin: 1.0        n_samples:9174      MAE:0.16164146122370482

# %% [markdown]
# ## X: AE Y: overlap_area_error

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_error', logx=False, logy=False, limit_y=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='AE', label_y='overlap_area_error', logx=True, logy=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## X: overlap_area_pred Y: overlap_area_true

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=False, logy=False, plot_bisector=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_y='overlap_area_pred', label_x='overlap_area_true', logx=True, logy=True, plot_bisector=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## X: overlap_area_AE Y: overlap_area_true

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', 
    label_x='overlap_area_AE',label_y='overlap_area_true',
    logx=False, logy=False, plot_bisector=False, x_limit_left=0, x_limit_right=900, y_limit_low=0, y_limit_up=1800,
    limit_x=True, limit_y=True)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_area_scatter_plot('/home/francesco.pugnaloni/GNNTE/test_data/performance/samples_enriched_for_plotting.csv', label_x='overlap_area_AE',label_y='overlap_area_true',  logx=True, logy=True, plot_bisector=False)
# Out:
# /home/francesco.pugnaloni/miniconda3/envs/GNNTE/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Baseline comparison

# %% [markdown]
# ## Comparison with baseline overall

# %%
plot_box_group('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/baseline_performances/test_set_similarities_gittables_with_armadillo_predictions.csv', label_list=['AE_armadillo', 'AE_josie','AE_jsim', ])

# %% [markdown]
# ## Comparison with baseline per correct label bin

# %%
df = compare_models_hist('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/baseline_performances/test_set_similarities_gittables_with_armadillo_predictions.csv')

# %%
df
# Out:
#    Correct Label Range                Approach   MAE
# 0            [0.0,0.1]               Armadillo  0.08
# 1            [0.0,0.1]  Overlap Set Similarity  0.18
# 2            [0.0,0.1]      Jaccard Similarity  0.05
# 3            [0.1,0.2]               Armadillo  0.11
# 4            [0.1,0.2]  Overlap Set Similarity  0.34
# 5            [0.1,0.2]      Jaccard Similarity  0.14
# 6            [0.2,0.3]               Armadillo  0.10
# 7            [0.2,0.3]  Overlap Set Similarity  0.35
# 8            [0.2,0.3]      Jaccard Similarity  0.16
# 9            [0.3,0.4]               Armadillo  0.13
# 10           [0.3,0.4]  Overlap Set Similarity  0.28
# 11           [0.3,0.4]      Jaccard Similarity  0.23
# 12           [0.4,0.5]               Armadillo  0.11
# 13           [0.4,0.5]  Overlap Set Similarity  0.16
# 14           [0.4,0.5]      Jaccard Similarity  0.18
# 15           [0.5,0.6]               Armadillo  0.08
# 16           [0.5,0.6]  Overlap Set Similarity  0.12
# ...

# %%
pd.read_csv('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/baseline_performances/test_set_similarities_gittables_with_armadillo_predictions.csv')
# Out:
#                                                     r_id  \
# 0          seek_time_csv_licensed.zip_PL1331LAGS2BRH.csv
# 1      in_time_csv_licensed.zip_0203_002257_Initializ...
# 2                  id_csv_licensed.zip_01_language_5.csv
# 3      in_time_csv_licensed.zip_0224_015304_Initializ...
# 4      object_csv_licensed.zip_Configuration3_window2...
# ...                                                  ...
# 99995        time_interval_csv_licensed.zip_00-01_16.csv
# 99996        running_time_csv_licensed.zip_02-03_303.csv
# 99997              thing_csv_licensed.zip_03-04_1114.csv
# 99998              object_csv_licensed.zip_20-21_158.csv
# 99999      id_csv_licensed.zip_ir.model.access_86471.csv
#
#                                                     s_id        a%      jsim  \
# 0          seek_time_csv_licensed.zip_PL1331LAGTN98H.csv  0.473684  0.238009
# 1      in_time_csv_licensed.zip_0212_004622_Initializ...  0.500000  0.502674
# ...

# %%
dd = plot_data_distribution('/home/francesco.pugnaloni/GNNTE/Datasets/1_Gittables/baseline_performances/test_set_similarities_gittables_with_armadillo_predictions.csv', label='overlap_armadillo')

# %%
dd

# %% [markdown]
# ## Overlap of a pair: efficiency

# %% [markdown]
# ##
